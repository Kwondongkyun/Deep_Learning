# %%
my_list = [10, 'list', 20]
print(my_list[1])
# Out:
# list

# %%
my_list_2 = [[10, 20, 30], [40, 50, 60]]
print(my_list_2[0][2])
# Out:
# 30

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.19.5

# %%
my_arr = np.array([[10, 20, 30], [40, 50, 60]])
print(my_arr)
type(my_arr)
# Out:
# [[10 20 30]
#  [40 50 60]]
# numpy.ndarray

# %%
my_arr[0][2]
# Out:
# 30

# %%
np.sum(my_arr)
# Out:
# 210

# %% [markdown]
# # 새 섹션
